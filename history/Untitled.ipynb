# %%
import requests
res = requests.get('http://data.taipei/youbike')

# %%
ary = []
ret = res.json()['retVal']
for k in ret:
    ary.append(ret[k])
    
import pandas
df = pandas.DataFrame(ary)

# %%
df
# Out:
#     act                             ar  \
# 0     1                  忠孝東路/松仁路(東南側)
# 1     1              忠孝東路四段/光復南路口(西南側)
# 2     1                  台北市政府東門(松智路)
# 3     1                  市府路/松壽路(西北側)
# 4     1                松仁路/松仁路95巷(東南側)
# 5     1                  松智路/松廉路(東北側)
# 6     1                  松智路/信義路(東北側)
# 7     1                  市府路/松壽路(東南側)
# 8     1                  台北市信義區松德路300號
# 9     1             台北市信義區莊敬路391巷11弄2號
# 10    1                 光復南路/基隆路一段364巷
# 11    1             台北醫學大學(吳興街220巷59弄)
# 12    1                   大道路/福德街路口北西側
# 13    1                  五常街/龍江路口(西南側)
# 14    1                   八德路/松信路(西南側)
# 15    1                   林口街/福德街(東南側)
# 16    1                 光復北路/民生東路(西北側)
# 17    1                      八德路三段25號前
# 18    1                   松仁路153巷17號對面
# 19    1              科技大樓站對面(復興南路2段西側)
# 20    1                     敦化民生路口公車站旁
# 21    1                  松山車站西出口外自行車格內
# 22    1                東新國小側門(東明街62號前)
# ...
