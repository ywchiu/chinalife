# %% [markdown]
# ## Python basic

# %%
a = 3 
b = 2
a + b
# Out:
# 5

# %%
a * 10
# Out:
# 30

# %%
a * 5
# Out:
# 15

# %% [markdown]
# ## 台銀匯率抓取

# %%
import pandas
dfs = pandas.read_html('https://rate.bot.com.tw/xrt/quote/l6m/USD')

# %%
df = dfs[0]
df = df.iloc[:,0:6]

# %%
df.columns = ['掛牌日期','幣別', '現金匯率-本行買入','現金匯率-本行賣出','即期匯率-本行買入','即期匯率-本行賣出']

# %%
df['掛牌日期'] = pandas.to_datetime(df['掛牌日期'], format = '%Y/%m/%d')

# %%
df.set_index('掛牌日期', inplace=True)

# %%
df.sort_index(inplace=True)

# %%
# %pylab inline
df['現金匯率-本行賣出'].plot(kind= 'line')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df['ma30'] =  df['現金匯率-本行賣出'].rolling(window = 30).mean()

# %%
df[['現金匯率-本行賣出', 'ma30']].plot(kind= 'line')

# %%
df.to_excel('rateUSD.xlsx')

# %% [markdown]
# ## 數字

# %%
3 + 2 * 8
# Out:
# 19

# %%
2 + 1
# Out:
# 3

# %%
2 - 1
# Out:
# 1

# %%
2 * 3
# Out:
# 6

# %%
3 / 2
# Out:
# 1.5

# %%
2 ** 3
# Out:
# 8

# %%
4 ** (0.5)
# Out:
# 2.0

# %%
2 + 10 * 10 + 3
# Out:
# 105

# %%
(2 + 10) * (10 + 3)
# Out:
# 156

# %%
a = 5

# %%
a
# Out:
# 5

# %%
a + a
# Out:
# 10

# %%
a = 10

# %%
a
# Out:
# 10

# %%
a = a + a

# %%
a
# Out:
# 20

# %%
price = 49.99
exchange_rate = 32.33

# %%
price * exchange_rate
# Out:
# 1616.1767

# %%
ntd_price = price * exchange_rate

# %%
ntd_price
# Out:
# 1616.1767

# %%
PRICE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-d3b79827e3c0> in <module>()
# ----> 1 PRICE
#
# NameError: name 'PRICE' is not defined

# %% [markdown]
# ## 字串

# %%
'Hello World'
# Out:
# 'Hello World'

# %%
"Hello World"
# Out:
# 'Hello World'

# %%
'i'm 18 years old'
# Out:
#   File "<ipython-input-53-1188d58efc8d>", line 1
#     'i'm 18 years old'
#        ^
# SyntaxError: invalid syntax

# %%
"i'm 18 years old"
# Out:
# "i'm 18 years old"

# %%
'寶寶心理苦，但寶寶不說'
# Out:
# '寶寶心理苦，但寶寶不說'

# %%
'hello'
'world'
# Out:
# 'world'

# %%
print('hello')
print('world')
# Out:
# hello
# world

# %%
print('Hello world 1')
print('Hello world 2')
print('Use \n to print a new line')
print('\n')
print('See what i mean?')
# Out:
# Hello world 1
# Hello world 2
# Use
#  to print a new line
#
#
# See what i mean?

# %%
print('1 2 3\n100 200 300')
# Out:
# 1 2 3
# 100 200 300

# %%
print('1\t2\t3\n100\t200\t300')
# Out:
# 1	2	3
# 100	200	300

# %%
print('hello')
# Out:
# hello

# %%
print('looooooooooooooooooooooooooooooooooooo\
oooooooooooooooooooooooooooooo text')
# Out:
# looooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooo text

# %%
print('''
paragraph1
paragraph2
paragraph3
''')
# Out:
# paragraph1
# paragraph2
# paragraph3

# %%
print("""
paragraph1
paragraph2
paragraph3
""")
# Out:
# paragraph1
# paragraph2
# paragraph3

# %%
s = 'Hello'

# %%
print(s)
# Out:
# Hello

# %%
s[0]
# Out:
# 'H'

# %%
s[1]
# Out:
# 'e'

# %%
len(s)
s[len(s)-1]
# Out:
# 'o'

# %%
s[-1]
# Out:
# 'o'

# %%
s[-5]
# Out:
# 'H'

# %%
s[-2]
# Out:
# 'l'

# %%
s
# Out:
# 'Hello'

# %%
# 字串[開頭位置:結尾位置]
s[:]
# Out:
# 'Hello'

# %%
s[1:]
# Out:
# 'ello'

# %%
# 只取到位置 3 之前的字串出來
# for(i=0 ; i < 3; i++)
# 0, 1, 2
s[:3]
# Out:
# 'Hel'

# %%
# for(i=1 ; i < 3; i++)
s[1:3]
# Out:
# 'el'

# %%
s = 'hello.txt'
s[-3:]
# Out:
# 'txt'

# %%
s = '[面試] 台積英文測驗'
s[1:3]
# Out:
# '面試'

# %%
s = 'Hello'

# %%
s
# Out:
# 'Hello'

# %%
s[:]
# Out:
# 'Hello'

# %%
# 字串[開頭位置:結束位置:跳字元數]
s[::]
# Out:
# 'Hello'

# %%
# for(i = 0; i< len(s); i++)
s[::1]
# Out:
# 'Hello'

# %%
# for(i = 0; i< len(s); i+=2)
# 0, 2, 4
s[::2]
# Out:
# 'Hlo'

# %%
# for(i = 1; i< 5; i+=2)
s[1:5:2]
# Out:
# 'el'

# %%
# for(i=len(s); i > 0; i--)
s[::-1]
# Out:
# 'olleH'

# %%
p ='上海自來水來自海上'

# %%
p[::-1]
# Out:
# '上海自來水來自海上'

# %%
p == p[::-1]
# Out:
# True

# %%
s[0]
# Out:
# 'H'

# %%
s[0] = 'X'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-68d9ab99b09c> in <module>()
# ----> 1 s[0] = 'X'
#
# TypeError: 'str' object does not support item assignment

# %%
s = 'Xello'

# %%
s = 'Hello'

# %%
s + 'World'
# Out:
# 'HelloWorld'

# %%
s = '對不起'
s * 10
# Out:
# '對不起對不起對不起對不起對不起對不起對不起對不起對不起對不起'

# %%
type(s)
# Out:
# str

# %%
print(dir(s))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
s = 'Hello'

# %%
help(s.lower)
# Out:
# Help on built-in function lower:
#
# lower(...) method of builtins.str instance
#     S.lower() -> str
#
#     Return a copy of the string S converted to lowercase.

# %%
# ?s.lower

# %%
s
# Out:
# 'Hello'

# %%
s.upper()
# Out:
# 'HELLO'

# %%
s.lower()
# Out:
# 'hello'

# %%
len(s)
# Out:
# 5

# %%
s.count('l')
# Out:
# 2

# %%
s = '''
鏡週刊今天(27日)報導指鴻海集團創辦人郭台銘的兒子郭守正曾向友人透露郭台銘確定不會等「換瑜」，預計9月宣布參選。對此，郭台銘幕僚蔡沁瑜表示，郭台銘與郭守正從未針對「換瑜」有過期待，也從未對外有過相關評論。至於在9月發動連署參選一事，蔡沁瑜說，是否宣布參選的最後期限是9月17日，郭台銘仍在慎重思考中。#央廣記者劉品希的採訪報導#

鏡週刊報導，針對2020年總統大選，以鴻海集團創辦人郭台銘為首，結合台北市長柯文哲及立委王金平組成的第三勢力參選態勢明確，三方將以「台灣的第三條路」為號召持續備戰，郭陣營已私下籌設競選團隊，預計在9月宣布投入大選，並以手機發動連署。報導並指出，郭台銘的兒子郭守正近日曾親口對友人說，確定不會等國民黨換掉韓國瑜。

對此，郭台銘幕僚、永齡基金會副執行長蔡沁瑜27日上午受訪時表示，郭台銘與郭守正從未針對「換瑜」有過期待，也沒有對外有過相關評論，該報導內容實屬臆測。至於郭台銘是否將在9月發動連署、宣布參選，蔡沁瑜則說，是否宣布參選的最後期限確實為9月17日，目前郭台銘仍在慎重思考中。她說：『(原音) 郭台銘先生跟郭守正先生從來也沒有對外有提出這樣子的相關的評論，而且從來對於「換瑜」這件事情也沒有期待，所以也沒有等的問題，相關的報導純屬臆測。那你說時間點的部分，我們大家都知道，9月17號是deadline，所以郭先生目前為止，都還在慎重地思考當中。』

媒體詢問評估參選的因素為何？蔡沁瑜表示，郭台銘思考的面向很多，包括台灣目前局勢、國際未來局勢、參選能否為解決台灣問題帶來良方、能解決到何種程度等，每一件事情都是郭台銘思考的重點。

至於脫黨與否，蔡沁瑜則說，讓中華民國贏、幫助國民黨重振黨魂及為人民找到經濟上的出路是郭台銘一路走來不變的使命，因此，在這個前提下，如何能使台灣2,300萬人過更好的未來才是他主要考量的重點，脫黨與否根本是不存在的議題。

'''

# %% [markdown]
# ### 小任務
# 1. 請計算字串s 的長度
# 2. 請找出s 裡面出現多少次"郭台銘"

# %%
len(s)
# Out:
# 798

# %%
s.count('郭台銘')
# Out:
# 15

# %%
s.split('。')
# Out:
# ['\n鏡週刊今天(27日)報導指鴻海集團創辦人郭台銘的兒子郭守正曾向友人透露郭台銘確定不會等「換瑜」，預計9月宣布參選',
#  '對此，郭台銘幕僚蔡沁瑜表示，郭台銘與郭守正從未針對「換瑜」有過期待，也從未對外有過相關評論',
#  '至於在9月發動連署參選一事，蔡沁瑜說，是否宣布參選的最後期限是9月17日，郭台銘仍在慎重思考中',
#  '#央廣記者劉品希的採訪報導#\n\n鏡週刊報導，針對2020年總統大選，以鴻海集團創辦人郭台銘為首，結合台北市長柯文哲及立委王金平組成的第三勢力參選態勢明確，三方將以「台灣的第三條路」為號召持續備戰，郭陣營已私下籌設競選團隊，預計在9月宣布投入大選，並以手機發動連署',
#  '報導並指出，郭台銘的兒子郭守正近日曾親口對友人說，確定不會等國民黨換掉韓國瑜',
#  '\n\n對此，郭台銘幕僚、永齡基金會副執行長蔡沁瑜27日上午受訪時表示，郭台銘與郭守正從未針對「換瑜」有過期待，也沒有對外有過相關評論，該報導內容實屬臆測',
#  '至於郭台銘是否將在9月發動連署、宣布參選，蔡沁瑜則說，是否宣布參選的最後期限確實為9月17日，目前郭台銘仍在慎重思考中',
#  '她說：『(原音) 郭台銘先生跟郭守正先生從來也沒有對外有提出這樣子的相關的評論，而且從來對於「換瑜」這件事情也沒有期待，所以也沒有等的問題，相關的報導純屬臆測',
#  '那你說時間點的部分，我們大家都知道，9月17號是deadline，所以郭先生目前為止，都還在慎重地思考當中',
#  '』\n\n媒體詢問評估參選的因素為何？蔡沁瑜表示，郭台銘思考的面向很多，包括台灣目前局勢、國際未來局勢、參選能否為解決台灣問題帶來良方、能解決到何種程度等，每一件事情都是郭台銘思考的重點',
#  '\n\n至於脫黨與否，蔡沁瑜則說，讓中華民國贏、幫助國民黨重振黨魂及為人民找到經濟上的出路是郭台銘一路走來不變的使命，因此，在這個前提下，如何能使台灣2,300萬人過更好的未來才是他主要考量的重點，脫黨與否根本是不存在的議題',
#  '\n\n']

# %%
s.find('換瑜')
# Out:
# 45

# %%
s[30:60]
# Out:
# '曾向友人透露郭台銘確定不會等「換瑜」，預計9月宣布參選。對此'

# %% [markdown]
# ## 輸出格式

# %%
name= 'David'
company = 'ChinaLife'
print(company + ' is ' + name + "'s favorite")
# Out:
# ChinaLife is David's favorite

# %%
name= 'David'
company = 'ChinaLife'
print("%s is %s's favorite"%(company, name))
# Out:
# ChinaLife is David's favorite

# %%
print('Floating point number: %1.2f' %(13.145))
     
print('Floating point number: %1.10f' %(13.145))
     
print('Floating point number: %25.3f' %(13.145))
# Out:
# Floating point number: 13.14
# Floating point number: 13.1450000000
# Floating point number:                    13.145

# %%
print('Here is a number: %s. Here is a string: %s' %(123.1,'hi'))

print('Here is a number: %r. Here is a string: %r' %(123.1,'hi'))
# Out:
# Here is a number: 123.1. Here is a string: hi
# Here is a number: 123.1. Here is a string: 'hi'

# %%
# 帶有 format 的 String 
raw = '\n\t this is a \t line with format \t\n'
print(raw)
# Out:
# 	 this is a 	 line with format

# %%
# 使用 r 取得raw string
raw = r'\n\t this is a \t line with format \t\n'
print(raw)
# Out:
# \n\t this is a \t line with format \t\n

# %%
# 使用 repr 取得string 中的表示
raw = repr('\n\t this is a \t line with format \t\n')
print(raw)
# Out:
# '\n\t this is a \t line with format \t\n'

# %%
# 根據樣式替代
print('This is a string with an {p}'.format(p='insert'))
# Out:
# This is a string with an insert

# %%
# 根據樣式替代多字串
print('One: {p}, Two: {p}, Three: {p}'.format(p='Hi!'))
# Out:
# One: Hi!, Two: Hi!, Three: Hi!

# %%
# 根據多樣式替代
print('Object 1: {a}, Object 2: {b}, Object 3: {c}'.format(a=1,b='two',c=12.3))
# Out:
# Object 1: 1, Object 2: two, Object 3: 12.3

# %%
# 根據位置替代
print('One: {0}, Two: {1}, One: {0}'.format(1,2))
# Out:
# One: 1, Two: 2, One: 1

# %%
stock = 'tsmc'
close = 200
print('%s price: %s'%(stock, close))
print('{stock} price: {price}'.format(stock = stock, price = close))
# Out:
# tsmc price: 200
# tsmc price: 200

# %%
stock = 'tsmc'
close = 200
a = f'{stock} price: {close}'
a
# Out:
# 'tsmc price: 200'

# %%
def upper(s):
    return s.upper()

stock = 'tsmc'
close = 200
#f'{stock} price: {close}’

#套用函數
f'{upper(stock)} price: {close}'
# Out:
# 'TSMC price: 200'

# %% [markdown]
# ## 資料輸入

# %%
input('請問我的保單到期了嗎?')
# Out:
# 請問我的保單到期了嗎?到期了
# '到期了'

# %%
answer = input('請問我的保單到期了嗎?')
# Out:
# 請問我的保單到期了嗎?到期了

# %%
answer
# Out:
# '到期了'

# %%
answer = input('請問我的保單到期了嗎?')
print(answer)
# Out:
# 請問我的保單到期了嗎?到期了
# 到期了

# %% [markdown]
# ## List

# %%
name1 = 'David'
name2 = 'John'
name3 = 'Marry'

# %%
a = []

# %%
type(a)
# Out:
# list

# %%
names = ['David', 'John', 'Marry']

# %%
my_list = [1,2,3]

# %%
my_list = [1, 'hello', 1.23]

# %%
a = [5,6,7,'s']

# %%
a[0]
# Out:
# 5

# %%
a[-1]
# Out:
# 's'

# %%
a[2:4]
# Out:
# [7, 's']

# %%
a[2:]
# Out:
# [7, 's']

# %%
a[2:100]
# Out:
# [7, 's']

# %%
a[::2]
# Out:
# [5, 7]

# %%
a[::-1]
# Out:
# ['s', 7, 6, 5]

# %%
len(a)
# Out:
# 4

# %%
a = [5,6,7,8]

# %%
a.pop()
# Out:
# 8

# %%
a
# Out:
# [5, 6, 7]

# %%
a.append(2)

# %%
a
# Out:
# [5, 6, 7, 2]

# %%
a.sort()

# %%
a
# Out:
# [2, 5, 6, 7]

# %%
a.reverse()

# %%
a
# Out:
# [7, 6, 5, 2]

# %%
print(dir(a))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
help(a.append)
# Out:
# Help on built-in function append:
#
# append(...) method of builtins.list instance
#     L.append(object) -> None -- append object to end

# %%
# ?a.append

# %%
list('a')
# Out:
# ['a']

# %%
list('hello world')
# Out:
# ['h', 'e', 'l', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd']

# %%
customers = ['c001','c002','c005','c008','c009']
'c005' in customers
# Out:
# True

# %%
'c003' in customers
# Out:
# False

# %%
a = 3
b = a

# %%
b
# Out:
# 3

# %%
b = 5

# %%
b
# Out:
# 5

# %%
a
# Out:
# 3

# %%
a = [1,2,3]
b = a

# %%
b
# Out:
# [1, 2, 3]

# %%
b[1] = 2000

# %%
b
# Out:
# [1, 2000, 3]

# %%
a
# Out:
# [1, 2000, 3]

# %%
a = [1,2,3]
b = a.copy()

# %%
b[1] = 2000

# %%
a
# Out:
# [1, 2, 3]

# %%
b
# Out:
# [1, 2000, 3]

# %% [markdown]
# ## 字典

# %%
dic = {'a': 100, 'b':'yes', 'c':0.98}

# %%
dic.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
dic.values()
# Out:
# dict_values([100, 'yes', 0.98])

# %%
dic['a']
# Out:
# 100

# %%
dic['d']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-203-2b1b63ca196d> in <module>()
# ----> 1 dic['d']
#
# KeyError: 'd'

# %%
dic.get('a')
# Out:
# 100

# %%
dic.get('d')

# %%
print(dic.get('d'))
# Out:
# None

# %%
# ?dic.get

# %%
dic.get('d', 'DEFAULT')
# Out:
# 'DEFAULT'

# %%
dic.get('a', 'DEFAULT')
# Out:
# 100

# %%
dic
# Out:
# {'a': 100, 'b': 'yes', 'c': 0.98}

# %%
dic['d'] = 'NEW'

# %%
dic
# Out:
# {'a': 100, 'b': 'yes', 'c': 0.98, 'd': 'NEW'}

# %%
dic.update({'d': 'NEWNEW', 'e': 3.14})

# %%
dic
# Out:
# {'a': 100, 'b': 'yes', 'c': 0.98, 'd': 'NEWNEW', 'e': 3.14}

# %%
dic = {
    '早安': '你也早安',
    '吃飽沒': '我吃過了, 你吃什麼?', 
    '晚安': '掰掰'
}

# %%
dic.get('早安')
# Out:
# '你也早安'

# %%
dic.get('請問路怎麼走')

# %%
dic.get('請問路怎麼走', '我現在還不聰明，等我以後變聰明後，再告訴你')
# Out:
# '我現在還不聰明，等我以後變聰明後，再告訴你'

# %% [markdown]
# ## 小任務
# - 今天有個對話機器人小L，他有內建一些智能對話庫。請根據以下需求設計程式：
#
# 1. 使用input 得到使用者的輸入，並將使用者的問題記錄在 question 這個變數之中
#
# 2. 請將以下智能對話庫建立於一字典之中：
#     - 問題：癌症要保什麼險? 回答：防癌險
#     - 問題：出國要保什麼險? 回答：旅平險
#     - 問題：出意外要保什麼險? 回答：意外險
#
# 3. 如果他都無法回答的話，請讓小L 回答：'我現在還不聰明，等我以後變聰明後，再告訴你'
